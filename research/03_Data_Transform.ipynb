# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'c:\\Users\\mukesk2\\OneDrive - kochind.com\\Tutorials\\MLOPS\\ML_Project1'

# %%
# %cd "c:/Users/mukesk2/OneDrive - kochind.com/Tutorials/MLOPS/ML_Project1"
# Out:
# c:\Users\mukesk2\OneDrive - kochind.com\Tutorials\MLOPS\ML_Project1
# c:\Users\mukesk2\AppData\Local\anaconda3\envs\MLProject_MLFlow\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %pwd
# Out:
# 'c:\\Users\\mukesk2\\OneDrive - kochind.com\\Tutorials\\MLOPS\\ML_Project1'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from MLProject.constants import *
from MLProject.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation
        

        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir=Path(config.root_dir),
            data_path=Path(config.data_path
        ))
        return data_transformation_config

# %%
import os
from MLProject import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config

    def train_test_split(self):
        data = pd.read_csv(self.config.data_path)
        train,test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir,"train.csv"),index=False)
        test.to_csv(os.path.join(self.config.root_dir,"test.csv"),index=False)
        logger.info("Train test split is done")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config=ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_split()
except Exception as e:
    raise e
# Out:
# [2025-12-09 21:17:13,233: INFO: common: yaml file: configs\config.yaml loaded successfully]
# [2025-12-09 21:17:13,235: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-12-09 21:17:13,237: INFO: common: yaml file: schema.yaml loaded successfully]
# [2025-12-09 21:17:13,238: INFO: common: created directory at: artifacts]
# [2025-12-09 21:17:13,239: INFO: common: created directory at: artifacts/data_transformation]
# [2025-12-09 21:17:13,263: INFO: 2148508086: Train test split is done]
# [2025-12-09 21:17:13,265: INFO: 2148508086: (1199, 12)]
# [2025-12-09 21:17:13,266: INFO: 2148508086: (400, 12)]
# (1199, 12)
# (400, 12)
